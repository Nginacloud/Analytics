# %%
my_dict = {"Name":"Oprah",
    "email": "everoprah@gmail.com",
    "place": "GardenCity"}

print(my_dict)
print(my_dict ["email"], my_dict ["place"])
# Out:
# {'Name': 'Oprah', 'email': 'everoprah@gmail.com', 'place': 'GardenCity'}
# everoprah@gmail.com GardenCity

# %%
for key, value in my_dict.items():
    print(f"{key}:{value}")
# Out:
# Name:Oprah
# email:everoprah@gmail.com
# place:GardenCity

# %% [markdown]
# pepit rules in python
#
# operations you can do in a list, tupple,set
#
# Create functions and classes in python
#
# how memories manage in python
